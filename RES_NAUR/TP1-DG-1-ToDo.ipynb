# %% [markdown]
# ## 1. IMPORT DES BIBLIOTHÈQUES

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. DATASET

# %%
# Toy Dataset : y = 2x + 1 + bruit
np.random.seed(42)

X = np.linspace(0, 10, 50)
bruit = np.random.randn(50) * 1.5
y = 2 * X + 1 + bruit

# %% [markdown]
# ## 3. VISUALISATION DES DONNÉES

# %%
plt.scatter(X, y)
plt.title("Dataset initial")
plt.xlabel("X")
plt.ylabel("y")
plt.show()

# %% [markdown]
# ## 4. INITIALISATION DES PARAMÈTRES

# %%
theta_0 = 0.0   # biais
theta_1 = 0.0   # pente

learning_rate = 0.01
epochs = 10

# %% [markdown]
# ## 5. FONCTIONS DE LA DESCENTE DU GRADIENT

# %%
def prediction(x, theta_1, theta_0):
    y = theta_1 * x + theta_0
    return y
    # calcul du y prédit


def cost_function(X, y, theta_1, theta_0):
    y_pred = prediction(X, theta_1, theta_0)
    mse = np.mean((y - y_pred) ** 2)
    return mse
    # calcul de MSE


def gradients(X, y, theta_1, theta_0):
    y_pred = prediction(X, theta_1, theta_0)
    n = len(X)
    d_theta_1 = (1/n) * np.sum((y_pred - y) * X)
    d_theta_0 = (1/n) * np.sum(y_pred - y)    
    theta_1 = learning_rate * d_theta_1
    theta_0 = learning_rate * d_theta_0
    # calcul du gradient des theta
    return d_theta_1, d_theta_0

# %%
# Desente du gradient
cost_history = []
cost = cost_function(X, y, theta_1, theta_0)

for epoch in range(epochs):
    
    # mise a jour des theta selon l'algo de la descente du gradient
# Out:
#   Cell In[7], line 6
#     # mise a jour des theta selon l'algo de la descente du gradient
#                                                                    ^
# SyntaxError: incomplete input

# %%
# Affichage des paramètres finaux
print("\nParamètres appris :")
print("theta_1 =", theta_1)
print("theta_0 =", theta_0)
# Out:
# Paramètres appris :
# theta_1 = 2.025759605358095
# theta_0 = 0.34299256032751774

# %% [markdown]
# ## 6. VISUALISATION

# %%
# visualiser le resultat de l'apprentissage
