# %%
import random
import math
import numpy as np

# %%
#F1 
def F1(x):
    resulta = 0.0
    for i in range(len(x)):
        resulta = resulta + x[i] * x[i]
    return resulta

# %%
def random_solution(D, min_val, max_val):
    x = []
    for _ in range(D):
        x.append(random.uniform(min_val, max_val))
    return x

# %%
# ntestiw ntestiw
D = 30
x_random = random_solution(D, -100, 100)
print("F1(x_random) =",x_random)
# Out:
# F1(x_random) = [-27.970429926758115, -37.26111361124871, 34.025884708459245, -95.79020864711187, 52.68611505965245, -57.30583602040813, 96.47017966832067, 36.31280889761351, -53.748389113858444, 5.016189680338215, -68.61267106308935, -33.62786365821569, -11.180628883359375, -73.36205258431887, -60.966659805399374, 50.97181454159369, -98.06879567830065, -53.246417939721226, 24.28989875354513, 19.61883061623719, 0.19185649433551077, 85.12288316261706, -90.6777000473963, -52.592096002401064, 12.90161637792771, -67.21946583742151, -92.77925181512714, 51.72714376945669, -64.60849305551639, -7.602465335951408]

# %%
# predef test
x_values = [-27.81, -71.96, -47.13, 54.63, -86.58, -96.77, 63.39, 75.60, -39.94, -45.13,
            90.77, 70.68, 36.61, 18.50, -46.11, -91.04, -34.74, 94.34, 61.98, -77.94,
            -78.75, -3.11, -2.81, 80.69, -76.95, 43.46, 3.65, -26.73, 49.26, 0.72]

# calcul F1
F1_result = np.sum(np.array(x_values)**2)
F1_result
# Out:
# 110433.254
